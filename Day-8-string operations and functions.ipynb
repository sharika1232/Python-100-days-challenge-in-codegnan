# %%
s="codegnan"

# %%
print(s)
# Out:
# codegnan

# %%
# string operations
## string operations

# %%
# concatination
s1 = "code"
s2 = "Gnan"
s3=s1+" "+s2
print(s3)
# Out:
# code Gnan

# %%
print(s1 + s1+ s1+ s1)
# Out:
# codecodecodecode

# %%
s="sarika"
print(s[0])
print("r" + s[1:])
print(s) #sarika to rarika
# Out:
# s
# rarika
# sarika

# %%
s="sarika"
print(s[0])
y= "r" + s[1:]
print(y,s)
# Out:
# s
# rarika sarika

# %%
print("code" + "9")
# Out:
# code9

# %%
#string repete
s= "codegnan"
print(s*5)
# Out:
# codegnancodegnancodegnancodegnancodegnan

# %%
### String functions
#case conversion function- lower(), upper(), title(), swapcase(), captilize()

# %%
s= "I Am Python Batch studenT"
print(len(s))
print(s.lower()) 
print(s.upper())
print(s.title()) # in all words frist letter is capital
print(s.swapcase()) # if a word is captital then convert to small letter
print(s.capitalize()) # in sentance frist word is captital another all are small
# Out:
# 25
# i am python batch student
# I AM PYTHON BATCH STUDENT
# I Am Python Batch Student
# i aM pYTHON bATCH STUDENt
# I am python batch student

# %%
# sub string index finding
# find()
# descreptions is know shift + tab
u= "I Am Python Batch studenT"
print(u.find("t"))
print(u.find("t", 10 )) # it will check the 10th position
print(s.find("z"))
print(s.index("t"))
#print(s.index("5")) # if there are no
# Out:
# 7
# 14
# -1
# 7

# %%
#strrip() -it removes the white space
t="                 sharika                  "
print(t)
print(t.strip())
print(t.lstrip())
print(t.rstrip())
# Out:
#                  sharika
# sharika
# sharika
#                  sharika

# %%
t="@@@@@@@@@@@@@@sha@@@@@rika@@@@@@@@@@@@@@"
print(t)
print(t.strip("@"))
print(t.lstrip())
print(t.rstrip("@"))
# Out:
# @@@@@@@@@@@@@@sha@@@@@rika@@@@@@@@@@@@@@
# sha@@@@@rika
# @@@@@@@@@@@@@@sha@@@@@rika@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@sha@@@@@rika

# %%
s= "I Am Python Batch studenT"
print(s.split())
# Out:
# ['I', 'Am', 'Python', 'Batch', 'studenT']

# %%
# case checking functions
s1= "CODE"
s2="gnan"
s3="123"
s4="abc123"
s5="Codegnan"
print(s1.isupper())
print(s2.isupper())
print(s1.islower())
print(s2.islower())
print(s3.isdigit())
print(s4.isdigit())
print(s4.isalnum())
print(s4.isalpha())
print(s5.isalpha())
# Out:
# True
# False
# False
# True
# True
# False
# True
# False
# True

# %%
"s" in "rikitha"
# Out:
# False

# %%
#username validation
      - minimum length - 8
      - atleast one uppercase and one lowercase letter
      - special charater ("_","@")
      - it contain digits
#password validation'''

# %%
#username and password validator using case check functions
#username
username=input("Enter username: ")
if len(username) >=8 and username[0].isalpha() : 
    for char in username:
        if char.isupper():
            has_upper=True
        elif char.islower():
            has_lower=True
        elif char.isdigit():
            has_digit=True
        elif char in ["_","@"]:
            has_special=True
    if has_upper and has_lower and has_digit and has_special:
        print("Username is valid!")
    else:
        print("Username is not valid!")
else:
    print("Username is not valid!")

#password 
password=input("Enter password: ")
if len(password) >=8 and password[0].isalpha() : 
    for char in password:
        if char.isupper():
            has_upper=True
        elif char.islower():
            has_lower=True
        elif char.isdigit():
            has_digit=True
        elif char in ["_","@"]:
            has_special=True
    if has_upper and has_lower and has_digit and has_special:
        print("Password is valid!")
    else:
        print("Password is not valid!")
else:
    print("Password is not valid!")
